# %% [markdown]
# Installing Libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import matplotlib.cm as cm

# %% [markdown]
# 1.Reading and Understanding the DATASET

# %%
#Reading the DATA_SET named CarPrice
#Note that df is a variable name can be kept anything else also like obj, var etc...
df = pd.read_excel('./CarPrice_datasheet.xlsx')

# %% [markdown]
# Understanding

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
# ...

# %%
# shape tells us the number of rows and columns we have 
df.shape
# Out:
# (205, 26)

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
#tells about mean std etc of each column
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
# Selecting numeric data types
numeric_df = df.select_dtypes(include=np.number)
len(numeric_df.columns)
# Out:
# 16

# %% [markdown]
# 2.DATA PREPROCESSING

# %% [markdown]
# Data preprocessing mainly contains data cleaning and data wrangling

# %% [markdown]
# Checking for the missing DATA

# %%
#Getting the DATA_SET info so that we know if the data needs cleaning
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
missing_values = df.isna().sum().sort_values(ascending=False)
missing_values
# Out:
# car_ID              0
# symboling           0
# highwaympg          0
# citympg             0
# peakrpm             0
# horsepower          0
# compressionratio    0
# stroke              0
# boreratio           0
# fuelsystem          0
# enginesize          0
# cylindernumber      0
# enginetype          0
# curbweight          0
# carheight           0
# carwidth            0
# carlength           0
# wheelbase           0
# enginelocation      0
# drivewheel          0
# carbody             0
# doornumber          0
# aspiration          0
# fueltype            0
# CarName             0
# price               0
# dtype: int64

# %%
plt.figure(figsize=(15,2))
missing_values.plot.bar()
#The plot will not show anything as we have zero missing values
# Out:
# <AxesSubplot:>

# %%
duplicates = df[df.duplicated()].sum().sort_values(ascending=False)

# %%
duplicates
# Out:
# car_ID              0.0
# symboling           0.0
# highwaympg          0.0
# citympg             0.0
# peakrpm             0.0
# horsepower          0.0
# compressionratio    0.0
# stroke              0.0
# boreratio           0.0
# fuelsystem          0.0
# enginesize          0.0
# cylindernumber      0.0
# enginetype          0.0
# curbweight          0.0
# carheight           0.0
# carwidth            0.0
# carlength           0.0
# wheelbase           0.0
# enginelocation      0.0
# drivewheel          0.0
# carbody             0.0
# doornumber          0.0
# aspiration          0.0
# fueltype            0.0
# CarName             0.0
# price               0.0
# dtype: float64

# %%
plt.figure(figsize=(15, 2))
duplicates.plot.bar()
plt.show()

# %% [markdown]
# Wrangling the DATA

# %%
#Splitting company name from CarName column
#we have split the company name and car model name and saved it into variable CompanyName
CompanyName = df['CarName'].apply(lambda x : x.split(' ')[0])

# %%
#inserting a new row named CompanyName into the cars dataframe
df.insert(3,"CompanyName",CompanyName)

# %%
print(df['CompanyName'])
# Out:
# 0      alfa-romero
# 1      alfa-romero
# 2      alfa-romero
# 3             audi
# 4             audi
#           ...
# 200          volvo
# 201          volvo
# 202          volvo
# 203          volvo
# 204          volvo
# Name: CompanyName, Length: 205, dtype: object

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName  CompanyName fueltype  \
# 0       1          3        alfa-romero giulia  alfa-romero      gas
# 1       2          3       alfa-romero stelvio  alfa-romero      gas
# 2       3          1  alfa-romero Quadrifoglio  alfa-romero      gas
# 3       4          2               audi 100 ls         audi      gas
# 4       5          2                audi 100ls         audi      gas
#
#   aspiration doornumber      carbody drivewheel enginelocation  ...  \
# 0        std        two  convertible        rwd          front  ...
# 1        std        two  convertible        rwd          front  ...
# 2        std        two    hatchback        rwd          front  ...
# 3        std       four        sedan        fwd          front  ...
# 4        std       four        sedan        4wd          front  ...
#
#    enginesize  fuelsystem  boreratio  stroke  compressionratio horsepower  \
# ...

# %%
ModelName = df['CarName'].apply(lambda x: x.split(' ')[1] if len(x.split(' ')) >= 2 else '')

# %%
df.insert(4,"ModelName",ModelName)

# %%
df['CompanyName'] = df['CompanyName'].str.capitalize()
df['CompanyName'].unique()
# Out:
# array(['Alfa-romero', 'Audi', 'Bmw', 'Chevrolet', 'Dodge', 'Honda',
#        'Isuzu', 'Jaguar', 'Maxda', 'Mazda', 'Buick', 'Mercury',
#        'Mitsubishi', 'Nissan', 'Peugeot', 'Plymouth', 'Porsche',
#        'Porcshce', 'Renault', 'Saab', 'Subaru', 'Toyota', 'Toyouta',
#        'Vokswagen', 'Volkswagen', 'Vw', 'Volvo'], dtype=object)

# %%
df.CompanyName.replace('Maxda','Mazda',inplace=True)
df.CompanyName.replace('Porcshce','Porsche',inplace=True)
df.CompanyName.replace('Toyouta','Toyota',inplace=True)
df.CompanyName.replace('Vokswagen','Volkswagen',inplace=True)
df.CompanyName.replace('Vw','Volkswagen',inplace=True)

df.CompanyName.unique()
# Out:
# array(['Alfa-romero', 'Audi', 'Bmw', 'Chevrolet', 'Dodge', 'Honda',
#        'Isuzu', 'Jaguar', 'Mazda', 'Buick', 'Mercury', 'Mitsubishi',
#        'Nissan', 'Peugeot', 'Plymouth', 'Porsche', 'Renault', 'Saab',
#        'Subaru', 'Toyota', 'Volkswagen', 'Volvo'], dtype=object)

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [car_ID, symboling, CarName, CompanyName, ModelName, fueltype, aspiration, doornumber, carbody, drivewheel, enginelocation, wheelbase, carlength, carwidth, carheight, curbweight, enginetype, cylindernumber, enginesize, fuelsystem, boreratio, stroke, compressionratio, horsepower, peakrpm, citympg, highwaympg, price]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# Showing the whole dataset

# %%
df
# Out:
#      car_ID  symboling                   CarName  CompanyName     ModelName  \
# 0         1          3        alfa-romero giulia  Alfa-romero        giulia
# 1         2          3       alfa-romero stelvio  Alfa-romero       stelvio
# 2         3          1  alfa-romero Quadrifoglio  Alfa-romero  Quadrifoglio
# 3         4          2               audi 100 ls         Audi           100
# 4         5          2                audi 100ls         Audi         100ls
# ..      ...        ...                       ...          ...           ...
# 200     201         -1           volvo 145e (sw)        Volvo          145e
# 201     202         -1               volvo 144ea        Volvo         144ea
# 202     203         -1               volvo 244dl        Volvo         244dl
# 203     204         -1                 volvo 246        Volvo           246
# 204     205         -1               volvo 264gl        Volvo         264gl
#
# ...

# %% [markdown]
# 3.DATA visualization

# %% [markdown]
# Histograms

# %%
def func_plot(x_axis,color_p1,color_p2):
    fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20, 5), facecolor='#333333')

    df1=df[x_axis].value_counts().sort_values(ascending=False)
    colors1 = cm.get_cmap(color_p1, len(df1))
    df1.plot(kind='bar', ax=ax1, color=colors1(range(len(df1))) )
    ax1.set_title(x_axis + ' Histogram')
    ax1.title.set_color('white')
    ax1.set_xlabel(x_axis,color='white')

    # Loop through the texts of axes and set their color to white
    for axis_texts in ax1.get_xticklabels() + ax1.get_yticklabels():
        axis_texts.set_color('white')
    
    df2 = pd.DataFrame(df.groupby([x_axis])['price'].mean().sort_values(ascending=False))
    df2.plot(kind='bar', ax=ax2, color=color_p2)
    ax2.set_title(x_axis + ' vs Mean Price')
    ax2.title.set_color('white')
    ax2.set_xlabel(x_axis,color='white')

    # Loop through the texts of axes and set their color to white
    for axis_texts in ax2.get_xticklabels() + ax2.get_yticklabels():
        axis_texts.set_color('white')

    plt.show()

# %% [markdown]
# Q.How many cars are there for each company in the dataset?
#
#     The histogram in the first subplot (ax1) shows the count of cars for each company.
#
# Q.What is the Mean(note: Here average and mean are same. ) price of cars for each company?
#
#     The bar chart in the second subplot (ax2) shows the mean price of cars for each company.

# %%
func_plot('CompanyName','magma','#6A176E')

# %% [markdown]
# Q.What is the distribution of different fuel types in the dataset? And Which fuel type is the most common or least common?
#
#     The first plot is a histogram showing the distribution of the 'fueltype' values.
#
# Q.Which fuel type tends to have the highest or lowest average price? And Is there a significant price difference between different fuel types?
#
#     The second plot compares the average price of cars based on the 'fueltype' category

# %%
func_plot('fueltype','tab10','aqua')

# %% [markdown]
# Similar visualizations are done for different columns

# %%
func_plot('aspiration','tab20b','#FFB6C1')

# %%
func_plot('doornumber','gist_rainbow','#D0700E')

# %%
func_plot('carbody','rainbow_r','#842B5A')

# %%
func_plot('drivewheel','cividis_r','#3B0A8C')

# %%
func_plot('enginelocation','inferno_r','#07062C')

# %%
func_plot('enginetype','viridis_r','#54098A')

# %%
func_plot('cylindernumber','cividis','#9F4835')

# %%
func_plot('enginelocation','nipy_spectral_r','grey')

# %%
func_plot('fuelsystem','gist_rainbow','olive')

# %% [markdown]
# Distribution plot

# %% [markdown]
# In a distribution plot, the x-axis typically represents the values of the variable being plotted, which in this case is the 'price' of cars. The y-axis represents the frequency or density of occurrence of those values.

# %% [markdown]
# Q.What is the distribution of car prices in the dataset?

# %%
plt.figure(figsize=(15, 5))
plt.title('Car Price Distribution Plot')
sns.histplot(df.price, kde=True, color='#E38400')
plt.xlabel('Price')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %% [markdown]
# Q.What is the spread or range of car prices?

# %%
plt.figure(figsize=(8,8))
plt.title('Car Price Spread')
sns.boxplot(y=df.price,color='#FDAE23')
plt.show()

# %% [markdown]
# PIE CHARTS

# %%
def plot_pie_chart(column_name, color_palette, explode_index=None):
    data = df[column_name].value_counts()

    # Extract the labels and sizes from the data
    labels = data.index.tolist()
    sizes = data.values.tolist()

    # Generate a color map with the same length as the number of categories
    colors = plt.cm.get_cmap(color_palette, len(labels))

    # Create the pie chart with exploding a slice
    fig, ax = plt.subplots(figsize=(16, 8))
    explode = [0] * len(labels)
    if explode_index is not None:
        explode[explode_index] = 0.2  # Explode the specified slice
    wedges, texts = ax.pie(sizes, colors=colors(range(len(labels))), radius=1.2, startangle=90, explode=explode)

    # Set border color for each wedge
    for wedge in wedges:
        wedge.set_edgecolor('brown')
    
    # Add percentage values to the legend
    percentages = [f'{size/sum(sizes)*100:.1f}%' for size in sizes]
    legend_labels = [f'{label} - {percentage}' for label, percentage in zip(labels, percentages)]
    ax.legend(wedges, legend_labels, loc='upper left', fontsize=8)

    # Set title and legend
    ax.set_title('Distribution of ' + column_name)

    # Set aspect ratio to make the pie chart a circle
    ax.axis('equal')

    # Show the chart
    plt.show()

# %%
plot_pie_chart('CompanyName','magma',0)

# %%
plot_pie_chart('enginetype','jet',0)

# %%
plot_pie_chart('carbody','rainbow',0)

# %%
plot_pie_chart('fuelsystem','viridis_r',0)

# %% [markdown]
# SCATTER PLOTS

# %% [markdown]
# The Scatter plot here mainly tells us about the corelation between the two specific columns

# %%
def plot_scatter(column1, column2, color_palette):
    # Extract the data from the columns
    data1 = df[column1]
    data2 = df[column2]
    
    # Find the correlation
    correlation = data1.corr(data2)
    print(correlation)
    
    if correlation > 0:
        relation = "Positive"
    elif correlation < 0:
        relation = "Negative"
    else:
        relation = "No Relation"

    # Set the color palette
    colors = sns.color_palette(color_palette, n_colors=len(data1))

    # Create a scatter plot
    plt.figure(figsize=(10, 6))
    plt.scatter(data1, data2, c=colors)

    # Set labels and title
    plt.xlabel(column1)
    plt.ylabel(column2)
    plt.title(f'{relation} Correlation between {column1} and {column2}')

    # Show the plot
    plt.show()

# %%
plot_scatter('wheelbase','carlength','magma')
# Out:
# 0.874587475964263

# %%
plot_scatter('horsepower','compressionratio','cividis')
# Out:
# -0.2043262261886782

# %%
plot_scatter('boreratio','enginesize','inferno_r')
# Out:
# 0.5837743274170981

# %%
plot_scatter('citympg','price','tab20')
# Out:
# -0.6857513360270401

# %%
plot_scatter('highwaympg','price','nipy_spectral')
# Out:
# -0.6975990916465566

# %%
plot_scatter('stroke','peakrpm','nipy_spectral')
# Out:
# -0.06796375316490946

# %%
plot_scatter('wheelbase','price','magma')
# Out:
# 0.5778155982921496

# %%
plot_scatter('carlength','price','magma')
# Out:
# 0.6829200156779629

# %%
plot_scatter('carwidth','price','magma')
# Out:
# 0.7593252997415118

# %%
plt.figure(figsize=(30,12))  

df1 = pd.DataFrame(df.groupby(['fuelsystem', 'drivewheel', 'carbody'])['price'].mean().unstack(fill_value=0))
df1.plot.bar(width=1)  # Increase the width of the bars to 0.8 or adjust as desired

plt.title('Car Range vs Average Price')
plt.show()

# %%
plt.figure(figsize=(30,12))  

df1 = pd.DataFrame(df.groupby(['aspiration', 'enginelocation', 'doornumber'])['price'].mean().unstack(fill_value=0))
df1.plot.bar(width=1)  # Increase the width of the bars to 0.8 or adjust as desired

plt.title('Car Range vs Average Price')
plt.show()
